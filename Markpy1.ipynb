# %%
import requests
res = requests.get('http://www.taifex.com.tw/chinese/3/7_12_5.asp')

# %%
res.encoding ='UTF-8'
res.text
# Out:
# '\r\n<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd">\r\n<html xmlns="http://www.w3.org/1999/xhtml" lang="zh-TW">\r\n<head><link rel="image_src" type="image/jpeg" href="http://www.taifex.com.tw/chinese/images/fb_logo.jpg" /><meta property="og:image" content="http://www.taifex.com.tw/chinese/images/fb_logo.jpg"/>\r\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\r\n<title>交易資訊/三大法人/查詢/選擇權買賣權分計/依日期</title>\r\n\r\n<link href="../css/jquery-ui.css" rel="stylesheet">\r\n<script type="text/javascript" src="../js/jquery-latest.min.js"></script>\r\n<script type="text/javascript" src="../js/jquery-ui.min.js"></script>\r\n<script type="text/javascript" src="../js/jquery.ifixpng.js"></script>\r\n<script type="text/javascript" src="../js/jquery.ui.datepicker-zh-TW.js"></script>\r\n\r\n<link rel="stylesheet" type="text/css" href="../css/global.css" />\r\n<link rel="stylesheet" type="text/css" href="../css/content.css" />\r\n\r\n<script type="text/javascript" src="../js/jquery.ifixpng.js"></script>\r\n<script type="text/javascript">\r\n<!--\r\n$(function(){\r\n\t$(\'.fixpng\').ifixpng(); \r\n});\r\n-->\r\n</script>\r\n  <style>\r\n    article,aside,figure,figcaption,footer,header,hgroup,menu,nav,section {display:block;}\r\n    \r\n  </style>\r\n</head>\r\n<body>\r\n<div class="wrapper" style="_width:1300px">  \r\n    <!--Header Start-->\r\n    \r\n<link rel="stylesheet" type="text/css" href="../css/jquery-ui.css" />\r\n<script src="../js/jquery-ui-1.11.4.min.js" type="text/javascript"></script>\r\n<script src="../js/jquery.placeholder.min.js" type="text/javascript"></script>\r\n\r\n<script language="javascript">\r\n\r\n\r\nfunction winopen(url){\r\n\tvar str = "網址： " + url + "\\n\\n將連結到其他網站，\\n\\n請問是否確定？";\r\n\tvar str2 = "&nbsp;<br />網址： " + url + "&nbsp;<br />&nbsp;<br />將連結到其他網站，請問是否確定？&nbsp;<br />&nbsp;<br />";\r\n\tif (document.getElementById(\'div_popupbox\') == null) {\r\n\t\tif (confirm(str))\r\n\t\t{\r\n\t\t\twindow.open(url);\r\n\t\t}\r\n\t} else {\r\n\t\tlocation.href = "#";\r\n\t\tdocument.getElementById(\'popupbox_title\').innerHTML = "連結外網警示";\r\n\t\tdocument.getElementById(\'popupbox_comment\').innerHTML = str2;\r\n\t\tdocument.getElementById(\'popupbox_url\').value = url;\r\n\t\tdocument.getElementById("div_popupbox").style.display = "block";\r\n\t}\r\n}\r\n</script>\r\n\t<div class="header clearfix">\r\n        <h1 class="logo" title="網站名稱"><a href="/chinese/index.asp" title="回首頁"></a></h1>\r\n\r\n    <div class="ann1">\r\n      <div class="txt"></div>\r\n    </div>\t\r\n\t\t\r\n        <div class="header_nav01">\r\n            <ul>\r\n\t\t\t\t<li><a href="/eng/index.asp">English</a> / </li>\r\n                <li><a href="../sitemap/sitemap.asp">網站導覽</a> / </li>\r\n                <li><a href="/chinese/index.asp">回首頁</a> / </li>\r\n                <li><a href="http://epaper.taifex.com.tw" target="_blank">電子報訂閱</a></li>\r\n            </ul>\r\n        </div>\r\n        <div class="search">\r\n<form name="myHeaderform" id="myHeaderform" >\r\n<script language="javascript">\r\n\r\n\r\n\r\n\t\t\t\t\r\n\t $(function () {\r\n\t\t\t\t   $(\'input\').placeholder();\t \r\n\t\t\t\t   $("#pstring").autocomplete({\r\n\t\t\t\t\tsource: "", \r\n\t\t\t\t\tautoFocus: true\r\n\t\t\t\t\t });  \r\n\t\t\t\t\t$("#pstring").keyup(function() {\r\n\t\t\t\t\t   var keyword=$("#pstring").val();\r\n\t\t\t\t\t   var code =keyword.charCodeAt();\r\n\t\t\t\t\t   if($.trim(keyword)!= "" && code !=12288){\r\n\t\t\t\t\t\tcrossDomainAjax("http://www.taifex.com.tw/TS50Search/wildcard.ashx?term="+encodeURIComponent(keyword),function (data) {\r\n\t\t\t\t\t\t\t$("#pstring").autocomplete({\r\n\t\t\t\t\t\t\t\tsource: data, //搜尋網站的網址\r\n\t\t\t\t\t\t\t\tautoFocus: true\r\n\t\t\t\t\t\t\t});  \r\n\t\t\t\t\t\t});\r\n\t\t\t\t\t\t}\r\n\t\t\t\t  });  \r\n\r\n                var $data = "";\r\n                $.ajax({\r\n                    url: "http://www.taifex.com.tw/TS50Search/listhotkeyword.ashx",\r\n   ...

# %%
from bs4 import BeautifulSoup as bs
soup = bs(res.text,'html.parser')
soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd">
#
# <html lang="zh-TW" xmlns="http://www.w3.org/1999/xhtml">
# <head><link href="http://www.taifex.com.tw/chinese/images/fb_logo.jpg" rel="image_src" type="image/jpeg"/><meta content="http://www.taifex.com.tw/chinese/images/fb_logo.jpg" property="og:image"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>交易資訊/三大法人/查詢/選擇權買賣權分計/依日期</title>
# <link href="../css/jquery-ui.css" rel="stylesheet">
# <script src="../js/jquery-latest.min.js" type="text/javascript"></script>
# <script src="../js/jquery-ui.min.js" type="text/javascript"></script>
# <script src="../js/jquery.ifixpng.js" type="text/javascript"></script>
# <script src="../js/jquery.ui.datepicker-zh-TW.js" type="text/javascript"></script>
# <link href="../css/global.css" rel="stylesheet" type="text/css"/>
# <link href="../css/content.css" rel="stylesheet" type="text/css"/>
# <script src="../js/jquery.ifixpng.js" type="text/javascript"></script>
# <script type="text/javascript">
# <!--
# $(function(){
# 	$('.fixpng').ifixpng();
# });
# -->
# </script>
# <style>
#     article,aside,figure,figcaption,footer,header,hgroup,menu,nav,section {display:block;}
#
#   </style>
# </link></head>
# <body>
# <div class="wrapper" style="_width:1300px">
# <!--Header Start-->
# <link href="../css/jquery-ui.css" rel="stylesheet" type="text/css"/>
# <script src="../js/jquery-ui-1.11.4.min.js" type="text/javascript"></script>
# <script src="../js/jquery.placeholder.min.js" type="text/javascript"></script>
# <script language="javascript">
#
#
# function winopen(url){
# 	var str = "網址： " + url + "\n\n將連結到其他網站，\n\n請問是否確定？";
# 	var str2 = "&nbsp;<br />網址： " + url + "&nbsp;<br />&nbsp;<br />將連結到其他網站，請問是否確定？&nbsp;<br />&nbsp;<br />";
# 	if (document.getElementById('div_popupbox') == null) {
# 		if (confirm(str))
# 		{
# 			window.open(url);
# 		}
# 	} else {
# 		location.href = "#";
# 		document.getElementById('popupbox_title').innerHTML = "連結外網警示";
# 		document.getElementById('popupbox_comment').innerHTML = str2;
# 		document.getElementById('popupbox_url').value = url;
# 		document.getElementById("div_popupbox").style.display = "block";
# 	}
# }
# </script>
# <div class="header clearfix">
# <h1 class="logo" title="網站名稱"><a href="/chinese/index.asp" title="回首頁"></a></h1>
# <div class="ann1">
# <div class="txt"></div>
# </div>
# <div class="header_nav01">
# <ul>
# <li><a href="/eng/index.asp">English</a> / </li>
# <li><a href="../sitemap/sitemap.asp">網站導覽</a> / </li>
# <li><a href="/chinese/index.asp">回首頁</a> / </li>
# <li><a href="http://epaper.taifex.com.tw" target="_blank">電子報訂閱</a></li>
# </ul>
# </div>
# <div class="search">
# <form id="myHeaderform" name="myHeaderform">
# <script language="javascript">
#
#
#
#
# 	 $(function () {
# 				   $('input').placeholder();
# 				   $("#pstring").autocomplete({
# 					source: "",
# 					autoFocus: true
# 					 });
# 					$("#pstring").keyup(function() {
# 					   var keyword=$("#pstring").val();
# 					   var code =keyword.charCodeAt();
# 					   if($.trim(keyword)!= "" && code !=12288){
# 						crossDomainAjax("http://www.taifex.com.tw/TS50Search/wildcard.ashx?term="+encodeURIComponent(keyword),function (data) {
# 							$("#pstring").autocomplete({
# 								source: data, //搜尋網站的網址
# 								autoFocus: true
# 							});
# 						});
# 						}
# 				  });
#
#                 var $data = "";
#                 $.ajax({
#                     url: "http://www.taifex.com.tw/TS50Search/listhotkeyword.ashx",
#                     type: 'get',
#                     datatype: 'jsonp',
#                     jsonp: 'callback',
#                     jsonpCallback: 'jsonpCallback',
#                     success: function (data) {
#                         $data = JSON.parse(jsonpCallback(data));
#                         var count = 1;
#                         for (var i in $data) {
#                             setHotKeyword($data[i]);
#                             if (count < 5) {
#                                 $('.hk-list').append("、");
#                             }
#                             count++;
#                         }
#
#                     }
#                 });
#             });
# 				  function crossDomainAjax (url, successCallback) {
#
# 					// IE8 & 9 only Cross domain JSON GET request
# 					if ('XDomainRequest' in window && window.XDomainRequest !== null) {
#
# 						var xdr = new XDomainRequest(); // Use Microsoft XDR
# 						xdr.open('get', url);
# 						xdr.onload = function () {
# 							var dom  = new ActiveXObject('Microsoft.XMLDOM'),
# 								JSON = $.parseJSON(xdr.responseText);
#
# 							dom.async = false;
#
# 							if (JSON == null || typeof (JSON) == 'undefined') {
# 								JSON = $.parseJSON(data.firstChild.textContent);
# 							}
#
# 							successCallback(JSON); // internal function
# 						};
#
# 						xdr.onerror = function() {
# 							_result = false;
# 						};
#
# 						xdr.send();
# 					}
#
# 					// IE7 and lower can't do cross domain
# 					else if (navigator.userAgent.indexOf('MSIE') != -1 &&
# 							parseInt(navigator.userAgent.match(/MSIE ([\d.]+)/)[1], 10) < 8) {
# 					  return false;
# 					}
#
# 					// Do normal jQuery AJAX for everything else
# 					else {
# 						$.ajax({
# 							url: url,
# 							cache: false,
# 							dataType: 'json',
# 							type: 'GET',
# 							async: false, // must be set to false
# 							success: function (data, success) {
# 								successCallback(data);
# 							}
# 						});
# 					}
# 				}
#             function jsonpCallback(data) {
#                 return data;
#             }
#             function setHotKeyword(keyword) {
#                 var a = document.createElement('a');
#                 //var li = document.createElement('li');
#                 a.setAttribute('href', 'www.taifex.com.tw/TS50Search/SearchIndex.aspx?Keyword=' + keyword+'&languageType=chinese&FileType=htm,doc,xls,ppt,pdf'); //若英文網站多加languageType=eng
#                 a.setAttribute('title', keyword);
#                 a.setAttribute('class', 'blue-link');
#                 a.setAttribute('target', '_blank');
#                 a.innerHTML = keyword;
#                 $('.hk-list').append(a); //.append(li)
#             }
#
#
#
#
#
#
#
# 	function handleKeydown(){
# 	if (window.event.keyCode == 13) // 表示按下 enter
# 	{
# 	window.event.returnValue = false; // 取消 submit()
# 	searchgosubmit();
# 	}
#
# 	}
#
# 		function searchgosubmit(){
#
# 			if (document.getElementById("pstring").value==""){
# 				alert("請輸入搜尋字串!");
# 			}else{
#
#
# 		//var url='http://www.taifex.com.tw/TS50Search/SearchResult.asp?KW='+escape(document.myHeaderform.pstring.value)+'&DB=Taifex_new_C&ST=basic&RC=default&SBV=&S_LOCALE=Wording_TW';
# 		var url='http://www.taifex.com.tw/TS50Search/SearchIndex.aspx?Keyword='+escape(document.myHeaderform.pstring.value)+'&languageType=chinese&FileType=htm,doc,xls,ppt,pdf&SearchType=Fuzzy';
# 		window.open(url,'_blank');
# 		return;
# 			}
# 		}
#
#
#
# </script>
# <input id="pstring" name="pstring" onkeydown="handleKeydown();" placeholder="請輸入查詢字詞" type="text"/>
# <input name="h" type="HIDDEN" value="0">
# <input name="l" type="HIDDEN" value="0">
# <input name="o" type="HIDDEN" value="4">
# <input name="a" type="HIDDEN" value="">
# <input name="f" type="HIDDEN" value="0">
# <input name="t" type="HIDDEN" value="0">
# <input name="s" type="HIDDEN" value="2">
# <input name="q" type="HIDDEN" value="">
# <input name="e" type="HIDDEN" value="">
# <input name="n" type="HIDDEN" value="">
# <input name="fileaut" type="HIDDEN" value="">
# <input name="filename" type="HIDDEN" value="">
# <input name="filetype" type="HIDDEN" value="">
# <input name="rel_start" type="HIDDEN" value="1">
# <input name="rel_num" type="HIDDEN" value="10">
# <input name="sim_start" type="HIDDEN" value="1">
# <input name="sim_num" type="HIDDEN" value="10">
# <input name="property" type="HIDDEN" value="">
# <input name="property" type="HIDDEN" value="">
# <a class="btn_search" href="javascript:searchgosubmit();"></a>
# </input></input></input></input></input></input></input></input></input></input></input></input></input></input></input></input></input></input></input></form>
# </div>
# <div class="facebook">
# <a class="fb1" href="https://www.facebook.com/taifexsocial" target="_blank" title="臺灣期貨交易所 Facebook"></a>
# <a class="gg1" href="https://plus.google.com/111846617247693181728" target="_blank" title="臺灣期貨交易所 Google+"></a>
# <a class="ios" href="https://itunes.apple.com/tw/app/qi-jiao-suo/id686377410?l=zh&amp;mt=8" target="_blank" title="下載iOS APP"></a>
# <a class="android" href="https://play.google.com/store/apps/details?id=com.mitake.taifex.impl&amp;hl=zh_TW" target="_blank" title="下載Android APP"></a>
# <a class="rss" href="/chinese/11/RSS0.asp" target="_blank" title="RSS訂閱"></a>
# </div>
# <div class="header_nav02">
# <ul>
# <li class="nav01" onmouseout="javascript:mastermenu(0);" onmouseover="javascript:mastermenu(1)"><a href="/chinese/1/Welcome.asp"></a>
# <ul id="mastermenu_1" style="left:0px;width:140px;display:none;">
# <li><a href="/chinese/1/Welcome.asp">首長歡迎詞</a></li>
# <li><a href="/chinese/1/OriginOfEstablish.asp">沿革、宗旨、展望</a></li>
# <li><a href="/chinese/1/OrgPattern.asp">組織型態</a></li>
# <li><a href="/chinese/1/OrgStructure.asp">組織結構</a></li>
# <li><a href="/chinese/1/CorpLogo.asp">企業識別標誌</a></li>
# <li><a href="http://taifex.learn.hinet.net/about.php?lang=1" target="_blank">影音介紹</a></li>
# <li><a href="/chinese/1/AnnualRep.asp">年報</a></li>
# <li><a href="/chinese/1/International.asp">國際合作專區</a></li>
# <li><a href="/chinese/1/HistoryOfTaifex.asp">iTaifex博物館</a></li>
# <li><a href="/chinese/1/Map.asp">地圖</a></li>
# <li><a href="/chinese/1/ContactTAIFEX.asp">聯絡我們</a></li>
# </ul>
# </li>
# <li class="nav02" onmouseout="javascript:mastermenu(0);" onmouseover="javascript:mastermenu(2)"><a href="/chinese/2/Products.asp"></a>
# <ul id="mastermenu_2" style="left:0px;width:126px;display:none;">
# <li><a href="/chinese/2/TX.asp">股價指數期貨類</a></li>
# <li><a href="/chinese/2/STF.asp">個股期貨類</a></li>
# <li><a href="/chinese/2/GBF.asp">利率期貨類</a></li>
# <li><a href="/chinese/2/TXO.asp">股價指數選擇權類</a></li>
# <li><a href="/chinese/2/SSO.asp">個股選擇權類</a></li>
# <li><a href="/chinese/2/GDF.asp">商品期貨與選擇權類</a></li>
# <li><a href="/chinese/2/RTF.asp">匯率期貨類</a></li>
# <li><a href="/chinese/2/RTO.asp">匯率選擇權類</a></li>
# <li><a href="/chinese/2/DevelopPlan.asp">規劃中商品資訊</a></li>
# </ul>
# </li>
# <li class="nav03" onmouseout="javascript:mastermenu(0);" onmouseover="javascript:mastermenu(3)"><a href="/chinese/3/7_12_1.asp"></a>
# <ul id="mastermenu_3" style="left:0px;width:224px;display:none;">
# <li><a href="/chinese/3/3_1_1.asp">盤後資訊</a></li>
# <li><a href="/chinese/3/7_12_1.asp">三大法人</a></li>
# <li><a href="/chinese/3/7_8.asp">大額交易人未沖銷部位結構</a></li>
# <li><a href="/chinese/3/3_5.asp">每日外幣參考匯率查詢</a></li>
# <li><a href="/chinese/3/AppForm.asp">交易歷史資料申請</a></li>
# <li><a href="/chinese/3/dl_3_1_2.asp">資料下載專區</a></li>
# <li><a href="/chinese/3/InfoVendor.asp">資訊廠商</a></li>
# <li><a href="http://info512.taifex.com.tw" target="_blank">台灣期貨交易所行情資訊網站</a></li>
# <li><a href="/chinese/3/TradeHalt.asp">訊息面暫停交易之股票期貨及選擇權</a></li>
# </ul>
# </li>
# <li class="nav04" onmouseout="javascript:mastermenu(0);" onmouseover="javascript:mastermenu(4)"><a href="/chinese/4/MarketFramework.asp"></a>
# <ul id="mastermenu_4" style="left:0px;width:224px;display:none;">
# <li><a href="/chinese/4/MarketFramework.asp">交易制度</a></li>
# <li><a href="/chinese/4/FeeSchedules.asp">費率表</a></li>
# <li><a href="/chinese/4/TradingSystem.asp">電子交易系統</a></li>
# <li><a href="/chinese/4/TraderPL.asp">部位限制</a></li>
# <li><a href="/chinese/4/FCMList.asp">期貨商名冊</a></li>
# <li><a href="/chinese/4/Calendar.asp">行事曆</a></li>
# <li><a href="/chinese/4/ContractAdj.asp">股票期貨/選擇權契約調整相關事項</a></li>
# </ul>
# </li>
# <li class="nav05" onmouseout="javascript:mastermenu(0);" onmouseover="javascript:mastermenu(5)"><a href="/chinese/5/Clearing.asp"></a>
# <ul id="mastermenu_5" style="left:0px;width:140px;display:none;">
# <li><a href="/chinese/5/ClrProcess.asp">結算制度</a></li>
# <li><a href="/chinese/5/IndexMargining.asp">保證金</a></li>
# <li><a href="/chinese/5/SafeguardSystem.asp">財務安全保衛系統</a></li>
# <li><a href="/chinese/5/CMCriteria.asp">結算會員資格標準</a></li>
# <li><a href="/chinese/5/CMList2.asp">結算會員名冊</a></li>
# <li><a href="/chinese/5/PositionManagement.asp">部位管理</a></li>
# <li><a href="/chinese/5/FutIndxFSP.asp">最後結算價一覽表</a></li>
# <li><a href="/chinese/5/FutIndxPosSettled.asp">到期契約履約交割說明</a></li>
# <li><a href="/chinese/5/SettledBond.asp">可交割債券轉換因子表</a></li>
# <li><a href="/chinese/4/FeeSchedules.asp?menuid1=05">費率表</a></li>
# </ul>
# </li>
# <li class="nav06" onmouseout="javascript:mastermenu(0);" onmouseover="javascript:mastermenu(6)"><a href="/chinese/6/Infor.asp"></a>
# <ul id="mastermenu_6" style="left:0px;width:98px;display:none;">
# <li><a href="/chinese/6/Infor.asp">最新修訂資訊</a></li>
# <li><a href="/chinese/6/TaifexRule.asp">本公司市場規章</a></li>
# <li><a href="http://www.selaw.com.tw/" target="_blank">法令查詢</a></li>
# </ul>
# </li>
# <li class="nav07" onmouseout="javascript:mastermenu(0);" onmouseover="javascript:mastermenu(7)"><a href="/chinese/7/AnnualTrading.asp"></a>
# <ul id="mastermenu_7" style="left:0px;width:210px;display:none;">
# <li><a href="/chinese/7/DailyFCM.asp">期貨商交易量日報表</a></li>
# <li><a href="/chinese/7/WeeklyFCM.asp">期貨商交易量週報表</a></li>
# <li><a href="/chinese/7/MonthlyFCM.asp">期貨商交易量月報表</a></li>
# <li><a href="/chinese/7/YearlyFCM.asp">期貨商交易量年報表</a></li>
# <li><a href="/chinese/7/AnnualTrading.asp">各商品年成交量統計表</a></li>
# <li><a href="/chinese/7/MarketParticipant.asp">市場參與者統計</a></li>
# <li><a href="/chinese/7/7_10.asp">各類交易人各商品交易量統計表</a></li>
# <li><a href="/chinese/7/TradingStatistics1.asp">經紀、自營商交易量統計表</a></li>
# <li><a href="/chinese/7/TradingStatistics2.asp">各類交易人交易量統計表</a></li>
# <li><a href="/chinese/7/trade_volume.xls" target="_blank">前一月份各商品每日交易量統計表 </a></li>
# <li><a href="/chinese/7/VIXMinQuotesNew.asp">臺指選擇權波動率指數下載</a></li>
# <li><a href="/chinese/7/va01.asp">加值資料集</a></li>
# </ul>
# </li>
# <li class="nav08" onmouseout="javascript:mastermenu(0);" onmouseover="javascript:mastermenu(8)"><a href="/chinese/8/NetValuePerShare.asp"></a>
# <ul id="mastermenu_8" style="left:0px;width:336px;display:none;">
# <li><a href="/chinese/8/NetValuePerShare.asp">期貨商財務資料</a></li>
# <li><a href="/chinese/8/FCM4.asp">交易結算申請作業各項表單</a></li>
# <li><a href="/chinese/8/FCM5.asp">財務稽核申報作業各項表單</a></li>
# <li><a href="/chinese/8/FCM6.asp">期貨商會計制度範本</a></li>
# <li><a href="/chinese/8/FCM7.asp">期貨商內控標準規範</a></li>
# <li><a href="/chinese/8/FCM10.asp">IB內控標準規範</a></li>
# <li><a href="/chinese/8/FCM13.asp">期貨商公開資訊觀測站</a></li>
# <li><a href="/chinese/8/FCM11.asp">違規處置歷史案例</a></li>
# <li><a href="/chinese/8/FCM12.asp">媒體申報系統上傳格式</a></li>
# <li><a href="/chinese/8/SPANRiskParameterFile.asp">期貨商SPAN相關檔案下載</a></li>
# <li><a href="/chinese/8/ParticipationReq.asp">期貨業設置條件一覽表</a></li>
# <li><a href="/chinese/8/USReg.asp">期貨商向美國投資人推廣本公司期貨商品應注意之事項</a></li>
# <li><a href="/chinese/8/TechDocs.asp">電腦技術文件下載區</a></li>
# </ul>
# </li>
# <li class="nav09" onmouseout="javascript:mastermenu(0);" onmouseover="javascript:mastermenu(9)"><a href="/chinese/9/9_7.asp"></a>
# <ul id="mastermenu_9" style="left:0px;width:294px;display:none;">
# <li><a href="https://investor.taifex.com.tw" target="_blank">交易人個人資料查詢</a></li>
# <li><a href="/chinese/9/QueryPosition.asp">交易人部位查詢功能</a></li>
# <li><a href="/chinese/9/9_7.asp">問題與解答</a></li>
# <li><a href="/chinese/9/9_12.asp">常見市場規章案例解說專欄</a></li>
# <li><a href="/chinese/9/9_2.asp">專有名詞</a></li>
# <li><a href="/chinese/9/9_3_1.asp">教育宣導</a></li>
# <li><a href="/chinese/9/9_4.asp">選擇權理論價格計算</a></li>
# <li><a href="/chinese/9/9_6.asp">期貨交易糾紛類型</a></li>
# <li><a href="/chinese/9/9_1950.asp">1950消費者服務專線</a></li>
# <li><a href="/chinese/9/法人法規說明與介紹.doc" target="_blank">法人機構參與期貨市場法規之說明與介紹</a></li>
# <li><a href="/chinese/9/9_10.asp">期貨投資人資通安全維護手冊</a></li>
# <li><a href="/chinese/9/AppForms.asp">期貨交易教育中心相關申請表單</a></li>
# <li><a href="/chinese/9/資料查詢申請表.pdf" target="_blank">期貨商、交易人資料查詢申請表</a></li>
# <li><a href="/chinese/9/期貨商得受託從事期貨交易之國外期貨交易契約.xls">期貨商得受託從事期貨交易之國外期貨交易契約</a></li>
# <li><a href="/chinese/9/期交所各部門對外窗口名單.doc" target="_blank">期貨市場服務中心</a></li>
# <li><a href="http://taifex.learn.hinet.net/" target="_blank">期貨影音知識網</a></li>
# <li><a href="http://taifex.learn.hinet.net/elearn/" target="_blank">期貨與選擇權數位學習網</a></li>
# <li><a href="/chinese/9/臺灣期貨交易所金融市場基本架構資訊揭露報告.pdf" target="_blank">臺灣期貨交易所金融市場基本架構資訊揭露報告</a></li>
# <li><a href="/chinese/10/PromotePamphlet1.asp?menuid1=09">宣導手冊 </a></li>
# </ul>
# </li>
# <li class="nav10" onmouseout="javascript:mastermenu(0);" onmouseover="javascript:mastermenu(10)"><a href="/chinese/10/AnnualRep.asp"></a>
# <ul id="mastermenu_10" style="left:0px;width:112px;display:none;">
# <li><a href="/chinese/10/AnnualRep.asp">年報</a></li>
# <li><a href="/chinese/10/Pub1.asp">臺灣期貨雙月刊</a></li>
# <li><a href="/chinese/10/Pub4.asp">歷史定期性刊物</a></li>
# <li><a href="/chinese/10/PromotePamphlet1.asp">宣導手冊</a></li>
# <li><a href="/chinese/10/Abstract.asp">研究報告摘要</a></li>
# <li><a href="/chinese/10/AboutJournal.asp">期貨與選擇權學刊</a></li>
# </ul>
# </li>
# <li class="nav11" onmouseout="javascript:mastermenu(0);" onmouseover="javascript:mastermenu(11)"><a href="/chinese/11/News1.asp"></a>
# <ul id="mastermenu_11" style="left:0px;width:168px;display:none;">
# <li><a href="/chinese/11/News1.asp">公告</a></li>
# <li><a href="/chinese/11/News2.asp">新聞稿</a></li>
# <li><a href="/chinese/11/News3.asp">股票期貨/選擇權契約調整</a></li>
# <li><a href="/chinese/11/HisNews.asp">歷史資料區</a></li>
# <li><a href="/chinese/11/DailyMarketInfo.asp">每日市場資訊</a></li>
# <li><a href="/chinese/11/RSS0.asp">RSS資訊訂閱服務</a></li>
# </ul>
# </li>
# <li class="nav12" onmouseout="javascript:mastermenu(0);" onmouseover="javascript:mastermenu(12)"><a href="/chinese/12/FP1.asp"></a>
# <ul id="mastermenu_12" style="left:-48px;width:196px;display:none;">
# <li><a href="/chinese/12/FP1.asp">參與交易方式</a></li>
# <li><a href="/chinese/2/TX.asp?menuid1=12">商品面</a></li>
# <li><a href="/chinese/4/TraderPL.asp?menuid1=12">制度面</a></li>
# <li><a href="/chinese/5/CMList.asp?menuid1=12">期貨商暨結算會員資格一覽表</a></li>
# <li><a href="/chinese/4/FCMList.asp?menuid1=12">各式名冊</a></li>
# <li><a href="/chinese/10/PromotePamphlet1.asp?menuid1=12">宣導手冊</a></li>
# <li><a href="/chinese/12/QA.asp">問題與解答</a></li>
# <li><a href="/chinese/12/FP2.asp">外資進入臺灣期貨市場作業說明</a></li>
# <li><a href="/chinese/12/LEI.pdf" target="_blank">法人機構識別碼LEI</a></li>
# <li><a href="/chinese/1/ContactTAIFEX.asp?menuid1=12">聯絡我們</a></li>
# </ul>
# </li>
# <li class="nav13" onmouseout="javascript:mastermenu(0);" onmouseover="javascript:mastermenu(13)"><a href="/chinese/13/RelatedLinks1.asp"></a>
# <ul id="mastermenu_13" style="left:-36px;width:112px;display:none;">
# <li><a href="/chinese/13/RelatedLinks1.asp">主管機關</a></li>
# <li><a href="/chinese/13/RelatedLinks2.asp">證券期貨周邊單位</a></li>
# <li><a href="/chinese/13/RelatedLinks3.asp">國外交易所</a></li>
# <li><a href="/chinese/13/RelatedLinks4.asp">期貨商</a></li>
# <li><a href="/chinese/13/RelatedLinks5.asp">結算會員</a></li>
# <li><a href="/chinese/13/RelatedLinks6.asp">國際財金網站</a></li>
# <li><a href="/chinese/13/RelatedLinks7.asp">即時交易資訊</a></li>
# </ul>
# </li>
# </ul>
# <script type="text/javascript">
# function mastermenu(id){
# var i;
# for (i=1;i<=13;i++) {
# if (i == id) {
# document.getElementById('mastermenu_' + i).style.display='block';
# } else {
# document.getElementById('mastermenu_' + i).style.display='none';
# }
# }
# }
# </script>
# </div>
# </div>
# <div class="vision flash">
# <style type="text/css">
#         a img {
#                 border: none;
#         }
#         #headerbanner_pic {
#                 position: relative;
#                 width: 1000px;
#                 height: 154px;
#                 border: 0px solid #ccc;
#         }
#         #headerbanner_pic a.ad {
#                 position: absolute;   /* 讓圖片疊在一起 */
#                 z-index:8;
#         }
#         #headerbanner_pic .control {
#                 position: absolute;
#                 right: 4px;
#                 bottom: 1px;
#                 z-index:99;
#         }
#         #headerbanner_pic .control a {
#                 display: inline-block;
#                 margin: 0 3px;
#
#                 width:12px; height:20px;
# 				color:#fff;
# 				font-size:1 px;
# 				text-align:center;
#
#         }
#         #headerbanner_pic .control a.on {
#
# 				color:#F90;
#         }
#         #headerbanner_pic .select{ background:url(../images/vision_bottom.png) no-repeat; height:20px; width:1000px; position:absolute; top:135px; z-index:50;}
# </style>
# <script type="text/javascript">
# 	$(function(){
# 		var $block = $('#headerbanner_pic'),
# 			$ad = $block.find('.ad'),
# 			showIndex = 0,			// 預設要先顯示那一張
# 			fadeOutSpeed = 2000,	// 淡出的速度
# 			fadeInSpeed = 3000,		// 淡入的速度
# 			defaultZ = 10,			// 預設的 z-index
# 			isHover = false,
# 			timer, speed = 2000;	// 計時器及輪播切換的速度
#
# 		// 先把其它圖片的變成透明
# 		$ad.css({
# 			opacity: 0,
# 			zIndex: defaultZ - 1
# 		}).eq(showIndex).css({
# 			opacity: 1,
# 			zIndex: defaultZ
# 		});
#
# 		// 組出右下的按鈕
# 		var str = '';
# 		for(var i=0;i<$ad.length;i++){
# 			str += '<a href="#" id='+(i + 1)+'><font size=4>●</font></a>';
# 		}
# 		var $controlA = $('#headerbanner_pic').append($('<div class="select fixpng"><div class="control">' + str + '</div></div>').css('zIndex', defaultZ + 1)).find('.control a');
#
# 		// 當按鈕被點選時
# 		// 若要變成滑鼠滑入來切換時, 可以把 click 換成 mouseover
# 		$controlA.click(function(){
# 			// 取得目前點擊的號碼
# 			showIndex = $(this).attr('id') * 1 - 1;
#
# 			// 顯示相對應的區域並把其它區域變成透明
# 			$ad.eq(showIndex).stop().fadeTo(fadeInSpeed, 1, function(){
# 				if(!isHover){
# 					// 啟動計時器
# 					timer = setTimeout(autoClick, speed);
# 				}
# 			}).css('zIndex', defaultZ).siblings('a').stop().fadeTo(fadeOutSpeed, 0).css('zIndex', defaultZ - 1);
# 			// 讓 a 加上 .on
# 			$(this).addClass('on').siblings().removeClass('on');
#
# 			return false;
# 		}).focus(function(){
# 			$(this).blur();
# 		}).eq(showIndex).addClass('on');
#
# 		$block.hover(function(){
# 			isHover = true;
# 			// 停止計時器
# 			clearTimeout(timer);
# 		}, function(){
# 			isHover = false;
# 			// 啟動計時器
# 			timer = setTimeout(autoClick, speed);
# 		})
#
# 		// 自動點擊下一個
# 		function autoClick(){
# 			if(isHover) return;
# 			showIndex = (showIndex + 1) % $controlA.length;
# 			$controlA.eq(showIndex).click();
# 		}
#
# 		// 啟動計時器
# 		timer_header = setTimeout(autoClick, speed);
# 	});
# </script>
# <div id="brower_others" style="display:none">
# <div class="vision" id="headerbanner_pic">
# <a class="ad"><img border="0" height="154" src="/chinese/pic_banners/header/af_b_banner.jpg" width="1000"/></a>
# <a class="ad"><img border="0" height="154" src="/chinese/pic_banners/header/i5f.jpg" width="1000"/></a>
# <a class="ad"><img border="0" height="154" src="/chinese/pic_banners/header/FX.jpg" width="1000"/></a>
# <a class="ad"><img border="0" height="154" src="/chinese/pic_banners/header/FXOptions_C.jpg" width="1000"/></a>
# </div>
# </div>
# <script>
# 		document.getElementById("brower_others").style.display = "block";
# </script>
# </div>
# <div class="crumb"><a class="home" href="/chinese/index.asp" style="background:url(../images/icon_crumb.jpg) no-repeat left center; padding:0 0 0 17px; color:#0066ab;">首頁</a> &gt; <a href="/chinese/3/7_12_1.asp" style="color:#0066ab;">交易資訊</a> &gt; <a href="/chinese/3/7_12_1.asp" style="color:#0066ab;">三大法人</a> &gt; <a href="/chinese/3/7_12_1.asp" style="color:#0066ab;">查詢</a> &gt; <a href="/chinese/3/7_12_5.asp" style="color:#0066ab;">選擇權買賣權分計</a> &gt; <a href="/chinese/3/7_12_5.asp" style="color:#0066ab;">依日期</a> <a href="http://www.facebook.com/sharer/sharer.php?u=http%3A%2F%2Fwww.taifex.com.tw%2Fchinese%2F3%2F7%5F12%5F5%2Easp" target="_blank"><img height="16" src="/chinese/images/fb_share.png" width="16"/></a> <a href="https://plus.google.com/share?url=http%3A%2F%2Fwww.taifex.com.tw%2Fchinese%2F3%2F7%5F12%5F5%2Easp" target="_blank"><img height="16" src="/chinese/images/gp_share.png" width="16"/></a></div>
# <!--Header End-->
# <!--Container Start-->
# <div class="container clearfix page">
# <!--SidebarLeft Start-->
# <div class="sidebar_left">
# <div class="hd"><h2>交易資訊</h2></div>
# <div class="bd">
# <div class="bg">
# <ul class="level-1">
# <li id="id_03_01000000_1" style="padding-left:5px;">
# <img id="id_03_01000000_2" onclick="javascript:menuclick('id_03_01000000')" src="../images/level-open.jpg" style="cursor:pointer;float:left;"/>
# <a href='javascript:menuclick("id_03_01000000")' style="float:left; width:90%;">盤後資訊</a>
# <div class="clear"></div>
# <ul id="id_03_01000000" style="display:none;">
# <li id="id_03_01010000_1" style="padding-left:15px;">
# <img id="id_03_01010000_2" onclick="javascript:menuclick('id_03_01010000')" src="../images/level-open.jpg" style="cursor:pointer;float:left;"/>
# <a href='javascript:menuclick("id_03_01010000")' style="float:left; width:90%;">期貨</a>
# <div class="clear"></div>
# <ul id="id_03_01010000" style="display:none;">
# <li id="id_03_01010100_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/3_1_1.asp" style="float:left; width:90%;">期貨每日交易行情查詢</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_01010200_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/3_1_2.asp" style="float:left; width:90%;">期貨每日交易行情下載</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_01010300_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/3_1_3.asp" style="float:left; width:90%;">前30個交易日期貨每筆成交資料</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_01010400_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/3_1_4.asp" style="float:left; width:90%;">前30個交易日期貨價差委託成交概況表</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_01010500_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/3_1_5.asp" style="float:left; width:90%;">前30個交易日期貨價差每筆成交資料</a>
# <div class="clear"></div>
# </li>
# </ul>
# </li>
# <li id="id_03_01020000_1" style="padding-left:15px;">
# <img id="id_03_01020000_2" onclick="javascript:menuclick('id_03_01020000')" src="../images/level-open.jpg" style="cursor:pointer;float:left;"/>
# <a href='javascript:menuclick("id_03_01020000")' style="float:left; width:90%;">選擇權</a>
# <div class="clear"></div>
# <ul id="id_03_01020000" style="display:none;">
# <li id="id_03_01020100_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/3_2_2.asp" style="float:left; width:90%;">選擇權每日交易行情查詢</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_01020200_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/3_2_1.asp" style="float:left; width:90%;">選擇權每日交易行情簡表</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_01020300_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/3_2_3.asp" style="float:left; width:90%;">選擇權每日交易行情下載</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_01020400_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/3_2_4.asp" style="float:left; width:90%;">前30個交易日選擇權每筆成交資料</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_01020500_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/3_7.asp" style="float:left; width:90%;">選擇權每日Delta值</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_01020600_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/PCRatio.asp" style="float:left; width:90%;">臺指選擇權Put/Call比</a>
# <div class="clear"></div>
# </li>
# </ul>
# </li>
# <li id="id_03_01030000_1" style="padding-left:15px;">
# <img id="id_03_01030000_2" onclick="javascript:menuclick('id_03_01030000')" src="../images/level-open.jpg" style="cursor:pointer;float:left;"/>
# <a href='javascript:menuclick("id_03_01030000")' style="float:left; width:90%;">鉅額交易</a>
# <div class="clear"></div>
# <ul id="id_03_01030000" style="display:none;">
# <li id="id_03_01030100_1" style="padding-left:15px;">
# <img id="id_03_01030100_2" onclick="javascript:menuclick('id_03_01030100')" src="../images/level-open.jpg" style="cursor:pointer;float:left;"/>
# <a href='javascript:menuclick("id_03_01030100")' style="float:left; width:90%;">每日成交資訊</a>
# <div class="clear"></div>
# <ul id="id_03_01030100" style="display:none;">
# <li id="id_03_01030101_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/3_3_1.asp" style="float:left; width:90%;">逐筆撮合之單式委託成交</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_01030102_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/3_3_2_1.asp" style="float:left; width:90%;">逐筆撮合之組合式委託成交</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_01030103_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/3_3_3_1.asp" style="float:left; width:90%;">議價申報成交</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_01030104_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/3_3_1dl.asp" style="float:left; width:90%;">逐筆撮合之單式委託成交-下載</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_01030105_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/3_3_2dl.asp" style="float:left; width:90%;">逐筆撮合之組合式委託成交-下載</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_01030106_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/3_3_3dl.asp" style="float:left; width:90%;">議價申報成交-下載</a>
# <div class="clear"></div>
# </li>
# </ul>
# </li>
# <li id="id_03_01030200_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/3_3_3.asp" style="float:left; width:90%;">各商品成交資訊</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_01030300_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/3_3_4.asp" style="float:left; width:90%;">成交量統計</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_01030400_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/3_3_5dl.asp" style="float:left; width:90%;">各商品成交資訊-下載</a>
# <div class="clear"></div>
# </li>
# </ul>
# </li>
# <li id="id_03_01040000_1" style="padding-left:15px;">
# <img id="id_03_01040000_2" onclick="javascript:menuclick('id_03_01040000')" src="../images/level-open.jpg" style="cursor:pointer;float:left;"/>
# <a href='javascript:menuclick("id_03_01040000")' style="float:left; width:90%;">期貨商買賣日報表</a>
# <div class="clear"></div>
# <ul id="id_03_01040000" style="display:none;">
# <li id="id_03_01040100_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/fcm_fut_rep.asp" style="float:left; width:90%;">期貨</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_01040200_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/fcm_opt_rep.asp" style="float:left; width:90%;">選擇權</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_01040300_1" style="padding-left:15px;">
# <img id="id_03_01040300_2" onclick="javascript:menuclick('id_03_01040300')" src="../images/level-open.jpg" style="cursor:pointer;float:left;"/>
# <a href='javascript:menuclick("id_03_01040300")' style="float:left; width:90%;">鉅額交易</a>
# <div class="clear"></div>
# <ul id="id_03_01040300" style="display:none;">
# <li id="id_03_01040301_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/fcm_fut_bt_rep.asp" style="float:left; width:90%;">期貨</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_01040302_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/fcm_opt_bt_rep.asp" style="float:left; width:90%;">選擇權</a>
# <div class="clear"></div>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="bg">
# <ul class="level-1">
# <li id="id_03_02000000_1" style="padding-left:5px;">
# <img id="id_03_02000000_2" onclick="javascript:menuclick('id_03_02000000')" src="../images/level-open.jpg" style="cursor:pointer;float:left;"/>
# <a href='javascript:menuclick("id_03_02000000")' style="float:left; width:90%;">三大法人</a>
# <div class="clear"></div>
# <ul id="id_03_02000000" style="display:none;">
# <li id="id_03_02010000_1" style="padding-left:15px;">
# <img id="id_03_02010000_2" onclick="javascript:menuclick('id_03_02010000')" src="../images/level-open.jpg" style="cursor:pointer;float:left;"/>
# <a href='javascript:menuclick("id_03_02010000")' style="float:left; width:90%;">查詢</a>
# <div class="clear"></div>
# <ul id="id_03_02010000" style="display:none;">
# <li id="id_03_02010100_1" style="padding-left:15px;">
# <img id="id_03_02010100_2" onclick="javascript:menuclick('id_03_02010100')" src="../images/level-open.jpg" style="cursor:pointer;float:left;"/>
# <a href='javascript:menuclick("id_03_02010100")' style="float:left; width:90%;">總表</a>
# <div class="clear"></div>
# <ul id="id_03_02010100" style="display:none;">
# <li id="id_03_02010101_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/7_12_1.asp" style="float:left; width:90%;">依日期</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_02010102_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/7_12_1_1.asp" style="float:left; width:90%;">依週別</a>
# <div class="clear"></div>
# </li>
# </ul>
# </li>
# <li id="id_03_02010200_1" style="padding-left:15px;">
# <img id="id_03_02010200_2" onclick="javascript:menuclick('id_03_02010200')" src="../images/level-open.jpg" style="cursor:pointer;float:left;"/>
# <a href='javascript:menuclick("id_03_02010200")' style="float:left; width:90%;">區分期貨與選擇權二類</a>
# <div class="clear"></div>
# <ul id="id_03_02010200" style="display:none;">
# <li id="id_03_02010201_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/7_12_2.asp" style="float:left; width:90%;">依日期</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_02010202_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/7_12_2_1.asp" style="float:left; width:90%;">依週別</a>
# <div class="clear"></div>
# </li>
# </ul>
# </li>
# <li id="id_03_02010300_1" style="padding-left:15px;">
# <img id="id_03_02010300_2" onclick="javascript:menuclick('id_03_02010300')" src="../images/level-open.jpg" style="cursor:pointer;float:left;"/>
# <a href='javascript:menuclick("id_03_02010300")' style="float:left; width:90%;">區分各期貨契約</a>
# <div class="clear"></div>
# <ul id="id_03_02010300" style="display:none;">
# <li id="id_03_02010301_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/7_12_3.asp" style="float:left; width:90%;">依日期</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_02010302_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/7_12_3_1.asp" style="float:left; width:90%;">依週別</a>
# <div class="clear"></div>
# </li>
# </ul>
# </li>
# <li id="id_03_02010400_1" style="padding-left:15px;">
# <img id="id_03_02010400_2" onclick="javascript:menuclick('id_03_02010400')" src="../images/level-open.jpg" style="cursor:pointer;float:left;"/>
# <a href='javascript:menuclick("id_03_02010400")' style="float:left; width:90%;">區分各選擇權契約</a>
# <div class="clear"></div>
# <ul id="id_03_02010400" style="display:none;">
# <li id="id_03_02010401_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/7_12_4.asp" style="float:left; width:90%;">依日期</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_02010402_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/7_12_4_1.asp" style="float:left; width:90%;">依週別</a>
# <div class="clear"></div>
# </li>
# </ul>
# </li>
# <li id="id_03_02010500_1" style="padding-left:15px;">
# <img id="id_03_02010500_2" onclick="javascript:menuclick('id_03_02010500')" src="../images/level-open.jpg" style="cursor:pointer;float:left;"/>
# <a href='javascript:menuclick("id_03_02010500")' style="float:left; width:90%;">選擇權買賣權分計</a>
# <div class="clear"></div>
# <ul id="id_03_02010500" style="display:none;">
# <li id="id_03_02010501_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/7_12_5.asp" style="float:left; width:90%;">依日期</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_02010502_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/7_12_5_1.asp" style="float:left; width:90%;">依週別</a>
# <div class="clear"></div>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li id="id_03_02020000_1" style="padding-left:15px;">
# <img id="id_03_02020000_2" onclick="javascript:menuclick('id_03_02020000')" src="../images/level-open.jpg" style="cursor:pointer;float:left;"/>
# <a href='javascript:menuclick("id_03_02020000")' style="float:left; width:90%;">下載</a>
# <div class="clear"></div>
# <ul id="id_03_02020000" style="display:none;">
# <li id="id_03_02020100_1" style="padding-left:15px;">
# <img id="id_03_02020100_2" onclick="javascript:menuclick('id_03_02020100')" src="../images/level-open.jpg" style="cursor:pointer;float:left;"/>
# <a href='javascript:menuclick("id_03_02020100")' style="float:left; width:90%;">總表</a>
# <div class="clear"></div>
# <ul id="id_03_02020100" style="display:none;">
# <li id="id_03_02020101_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/7_12_6.asp" style="float:left; width:90%;">依日期</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_02020102_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/7_12_6_1.asp" style="float:left; width:90%;">依週別</a>
# <div class="clear"></div>
# </li>
# </ul>
# </li>
# <li id="id_03_02020200_1" style="padding-left:15px;">
# <img id="id_03_02020200_2" onclick="javascript:menuclick('id_03_02020200')" src="../images/level-open.jpg" style="cursor:pointer;float:left;"/>
# <a href='javascript:menuclick("id_03_02020200")' style="float:left; width:90%;">區分期貨與選擇權二類</a>
# <div class="clear"></div>
# <ul id="id_03_02020200" style="display:none;">
# <li id="id_03_02020201_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/7_12_7.asp" style="float:left; width:90%;">依日期</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_02020202_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/7_12_7_1.asp" style="float:left; width:90%;">依週別</a>
# <div class="clear"></div>
# </li>
# </ul>
# </li>
# <li id="id_03_02020300_1" style="padding-left:15px;">
# <img id="id_03_02020300_2" onclick="javascript:menuclick('id_03_02020300')" src="../images/level-open.jpg" style="cursor:pointer;float:left;"/>
# <a href='javascript:menuclick("id_03_02020300")' style="float:left; width:90%;">區分各期貨契約</a>
# <div class="clear"></div>
# <ul id="id_03_02020300" style="display:none;">
# <li id="id_03_02020301_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/7_12_8.asp" style="float:left; width:90%;">依日期</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_02020302_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/7_12_8_1.asp" style="float:left; width:90%;">依週別</a>
# <div class="clear"></div>
# </li>
# </ul>
# </li>
# <li id="id_03_02020400_1" style="padding-left:15px;">
# <img id="id_03_02020400_2" onclick="javascript:menuclick('id_03_02020400')" src="../images/level-open.jpg" style="cursor:pointer;float:left;"/>
# <a href='javascript:menuclick("id_03_02020400")' style="float:left; width:90%;">區分各選擇權契約</a>
# <div class="clear"></div>
# <ul id="id_03_02020400" style="display:none;">
# <li id="id_03_02020401_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/7_12_9.asp" style="float:left; width:90%;">依日期</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_02020402_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/7_12_9_1.asp" style="float:left; width:90%;">依週別</a>
# <div class="clear"></div>
# </li>
# </ul>
# </li>
# <li id="id_03_02020500_1" style="padding-left:15px;">
# <img id="id_03_02020500_2" onclick="javascript:menuclick('id_03_02020500')" src="../images/level-open.jpg" style="cursor:pointer;float:left;"/>
# <a href='javascript:menuclick("id_03_02020500")' style="float:left; width:90%;">選擇權買賣權分計</a>
# <div class="clear"></div>
# <ul id="id_03_02020500" style="display:none;">
# <li id="id_03_02020501_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/7_12_10.asp" style="float:left; width:90%;">依日期</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_02020502_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/7_12_10_1.asp" style="float:left; width:90%;">依週別</a>
# <div class="clear"></div>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="bg">
# <ul class="level-1">
# <li id="id_03_03000000_1" style="padding-left:5px;">
# <img id="id_03_03000000_2" onclick="javascript:menuclick('id_03_03000000')" src="../images/level-open.jpg" style="cursor:pointer;float:left;"/>
# <a href='javascript:menuclick("id_03_03000000")' style="float:left; width:90%;">大額交易人未沖銷部位結構</a>
# <div class="clear"></div>
# <ul id="id_03_03000000" style="display:none;">
# <li id="id_03_03010000_1" style="padding-left:15px;">
# <img id="id_03_03010000_2" onclick="javascript:menuclick('id_03_03010000')" src="../images/level-open.jpg" style="cursor:pointer;float:left;"/>
# <a href='javascript:menuclick("id_03_03010000")' style="float:left; width:90%;">查詢</a>
# <div class="clear"></div>
# <ul id="id_03_03010000" style="display:none;">
# <li id="id_03_03010100_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/7_8.asp" style="float:left; width:90%;">期貨大額交易人未沖銷部位結構表</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_03010200_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/7_9.asp" style="float:left; width:90%;">選擇權大額交易人未沖銷部位結構表</a>
# <div class="clear"></div>
# </li>
# </ul>
# </li>
# <li id="id_03_03020000_1" style="padding-left:15px;">
# <img id="id_03_03020000_2" onclick="javascript:menuclick('id_03_03020000')" src="../images/level-open.jpg" style="cursor:pointer;float:left;"/>
# <a href='javascript:menuclick("id_03_03020000")' style="float:left; width:90%;">下載</a>
# <div class="clear"></div>
# <ul id="id_03_03020000" style="display:none;">
# <li id="id_03_03020100_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/7_8_1.asp" style="float:left; width:90%;">期貨大額交易人未沖銷部位資料下載</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_03020200_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/7_9_1.asp" style="float:left; width:90%;">選擇權大額交易人未沖銷部位資料下載</a>
# <div class="clear"></div>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="bg">
# <ul class="level-1">
# <li id="id_03_04000000_1" style="padding-left:5px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/3_5.asp" style="float:left; width:90%;">每日外幣參考匯率查詢</a>
# <div class="clear"></div>
# </li>
# </ul>
# </div>
# <div class="bg">
# <ul class="level-1">
# <li id="id_03_05000000_1" style="padding-left:5px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/AppForm.asp" style="float:left; width:90%;">交易歷史資料申請</a>
# <div class="clear"></div>
# </li>
# </ul>
# </div>
# <div class="bg">
# <ul class="level-1">
# <li id="id_03_06000000_1" style="padding-left:5px;">
# <img id="id_03_06000000_2" onclick="javascript:menuclick('id_03_06000000')" src="../images/level-open.jpg" style="cursor:pointer;float:left;"/>
# <a href='javascript:menuclick("id_03_06000000")' style="float:left; width:90%;">資料下載專區</a>
# <div class="clear"></div>
# <ul id="id_03_06000000" style="display:none;">
# <li id="id_03_06010000_1" style="padding-left:15px;">
# <img id="id_03_06010000_2" onclick="javascript:menuclick('id_03_06010000')" src="../images/level-open.jpg" style="cursor:pointer;float:left;"/>
# <a href='javascript:menuclick("id_03_06010000")' style="float:left; width:90%;">交易資訊</a>
# <div class="clear"></div>
# <ul id="id_03_06010000" style="display:none;">
# <li id="id_03_06010100_1" style="padding-left:15px;">
# <img id="id_03_06010100_2" onclick="javascript:menuclick('id_03_06010100')" src="../images/level-open.jpg" style="cursor:pointer;float:left;"/>
# <a href='javascript:menuclick("id_03_06010100")' style="float:left; width:90%;">盤後資訊-期貨</a>
# <div class="clear"></div>
# <ul id="id_03_06010100" style="display:none;">
# <li id="id_03_06010101_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/dl_3_1_2.asp" style="float:left; width:90%;">期貨每日交易行情下載</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_06010102_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/dl_3_1_3.asp" style="float:left; width:90%;">前30個交易日期貨每筆成交資料</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_06010103_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/dl_3_1_4.asp" style="float:left; width:90%;">前30個交易日期貨價差委託成交概況表</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_06010104_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/dl_3_1_5.asp" style="float:left; width:90%;">前30個交易日期貨價差每筆成交資料</a>
# <div class="clear"></div>
# </li>
# </ul>
# </li>
# <li id="id_03_06010200_1" style="padding-left:15px;">
# <img id="id_03_06010200_2" onclick="javascript:menuclick('id_03_06010200')" src="../images/level-open.jpg" style="cursor:pointer;float:left;"/>
# <a href='javascript:menuclick("id_03_06010200")' style="float:left; width:90%;">盤後資訊-選擇權</a>
# <div class="clear"></div>
# <ul id="id_03_06010200" style="display:none;">
# <li id="id_03_06010201_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/dl_3_2_3.asp" style="float:left; width:90%;">選擇權每日交易行情下載</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_06010202_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/dl_3_2_4.asp" style="float:left; width:90%;">前30個交易日選擇權每筆成交資料</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_06010203_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/dl_3_7.asp" style="float:left; width:90%;">選擇權每日Delta值</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_06010204_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/dl_PCRatio.asp" style="float:left; width:90%;">臺指選擇權Put/Call比</a>
# <div class="clear"></div>
# </li>
# </ul>
# </li>
# <li id="id_03_06010300_1" style="padding-left:15px;">
# <img id="id_03_06010300_2" onclick="javascript:menuclick('id_03_06010300')" src="../images/level-open.jpg" style="cursor:pointer;float:left;"/>
# <a href='javascript:menuclick("id_03_06010300")' style="float:left; width:90%;">盤後資訊-鉅額交易</a>
# <div class="clear"></div>
# <ul id="id_03_06010300" style="display:none;">
# <li id="id_03_06010301_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/dl_3_3_1dl.asp" style="float:left; width:90%;">逐筆撮合之單式委託成交-下載</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_06010302_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/dl_3_3_2dl.asp" style="float:left; width:90%;">逐筆撮合之組合式委託成交-下載</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_06010303_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/dl_3_3_3dl.asp" style="float:left; width:90%;">議價申報成交-下載</a>
# <div class="clear"></div>
# </li>
# <li id="id_03_06010304_1" style="padding-left:15px">
# <img src="../images/level-li.jpg" style="float:left;"/>
# <a href="/chinese/3/dl_3_3_5dl.asp" style="float:left; width:90%;">各商品成交資訊-下載</a>
# <div class="clear"></div>
# </li>
# </ul>
# </li>
# <li id="id_03_06010400_1" style="padding-left:15px;">
# <img id="id_03_06010400_2" onclick="javascript:menuclick('id_03_06010400')" src="../images/level-open.jpg" style="cursor:pointer;float:left;"/>
# ...
# <td align="right" bgcolor="#D0E0F0" height="15" nowrap=""><div align="right"></div><div align="right">0</div></td>
# <td align="right" bgcolor="#D0E0F0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#D0E0F0" nowrap="">0</td>
# <td align="right" bgcolor="#D0E0F0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#D0E0F0" nowrap="">0</td>
# <td align="right" bgcolor="#D0E0F0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#D0E0F0" nowrap="">0</td>
# <td align="right" bgcolor="#D0E0F0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#D0E0F0" nowrap="">0</td>
# <td align="right" bgcolor="#D0E0F0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#D0E0F0" nowrap="">0</td>
# </tr>
# <tr class="12bk">
# <td align="center" bgcolor="#D0E0F0">外資</td>
# <td align="right" bgcolor="#D0E0F0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#D0E0F0" height="15" nowrap=""><div align="right"></div><div align="right">0</div></td>
# <td align="right" bgcolor="#D0E0F0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#D0E0F0" nowrap="">0</td>
# <td align="right" bgcolor="#D0E0F0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#D0E0F0" nowrap="">0</td>
# <td align="right" bgcolor="#D0E0F0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#D0E0F0" nowrap="">0</td>
# <td align="right" bgcolor="#D0E0F0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#D0E0F0" nowrap="">0</td>
# <td align="right" bgcolor="#D0E0F0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#D0E0F0" nowrap="">0</td>
# </tr>
# <tr class="12bk">
# <td align="center" bgcolor="#FFFFF0" rowspan="6">7</td>
# <td align="center" bgcolor="#FFFFF0" rowspan="6">非金<br>電選<br>擇權</br></br></td>
# <td align="center" bgcolor="#FFFFF0" rowspan="3">買<br>權</br></td>
# <td align="center" bgcolor="#FFFFF0">自營商</td>
# <td align="right" bgcolor="#FFFFF0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#FFFFF0" height="15" nowrap=""><div align="right"></div><div align="right">0</div></td>
# <td align="right" bgcolor="#FFFFF0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#FFFFF0" nowrap="">0</td>
# <td align="right" bgcolor="#FFFFF0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#FFFFF0" nowrap="">0</td>
# <td align="right" bgcolor="#FFFFF0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#FFFFF0" nowrap="">0</td>
# <td align="right" bgcolor="#FFFFF0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#FFFFF0" nowrap="">0</td>
# <td align="right" bgcolor="#FFFFF0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#FFFFF0" nowrap="">0</td>
# </tr>
# <tr class="12bk">
# <td align="center" bgcolor="#FFFFF0">投信</td>
# <td align="right" bgcolor="#FFFFF0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#FFFFF0" height="15" nowrap=""><div align="right"></div><div align="right">0</div></td>
# <td align="right" bgcolor="#FFFFF0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#FFFFF0" nowrap="">0</td>
# <td align="right" bgcolor="#FFFFF0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#FFFFF0" nowrap="">0</td>
# <td align="right" bgcolor="#FFFFF0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#FFFFF0" nowrap="">0</td>
# <td align="right" bgcolor="#FFFFF0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#FFFFF0" nowrap="">0</td>
# <td align="right" bgcolor="#FFFFF0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#FFFFF0" nowrap="">0</td>
# </tr>
# <tr class="12bk">
# <td align="center" bgcolor="#FFFFF0">外資</td>
# <td align="right" bgcolor="#FFFFF0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#FFFFF0" height="15" nowrap=""><div align="right"></div><div align="right">0</div></td>
# <td align="right" bgcolor="#FFFFF0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#FFFFF0" nowrap="">0</td>
# <td align="right" bgcolor="#FFFFF0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#FFFFF0" nowrap="">0</td>
# <td align="right" bgcolor="#FFFFF0" nowrap=""><font color="blue">1</font></td>
# <td align="right" bgcolor="#FFFFF0" nowrap="">0</td>
# <td align="right" bgcolor="#FFFFF0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#FFFFF0" nowrap="">0</td>
# <td align="right" bgcolor="#FFFFF0" nowrap=""><font color="blue">1</font></td>
# <td align="right" bgcolor="#FFFFF0" nowrap="">0</td>
# </tr>
# <tr class="12bk">
# <td align="center" bgcolor="#FFFFF0" rowspan="3">賣<br>權</br></td>
# <td align="center" bgcolor="#FFFFF0">自營商</td>
# <td align="right" bgcolor="#FFFFF0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#FFFFF0" height="15" nowrap=""><div align="right"></div><div align="right">0</div></td>
# <td align="right" bgcolor="#FFFFF0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#FFFFF0" nowrap="">0</td>
# <td align="right" bgcolor="#FFFFF0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#FFFFF0" nowrap="">0</td>
# <td align="right" bgcolor="#FFFFF0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#FFFFF0" nowrap="">0</td>
# <td align="right" bgcolor="#FFFFF0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#FFFFF0" nowrap="">0</td>
# <td align="right" bgcolor="#FFFFF0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#FFFFF0" nowrap="">0</td>
# </tr>
# <tr class="12bk">
# <td align="center" bgcolor="#FFFFF0">投信</td>
# <td align="right" bgcolor="#FFFFF0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#FFFFF0" height="15" nowrap=""><div align="right"></div><div align="right">0</div></td>
# <td align="right" bgcolor="#FFFFF0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#FFFFF0" nowrap="">0</td>
# <td align="right" bgcolor="#FFFFF0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#FFFFF0" nowrap="">0</td>
# <td align="right" bgcolor="#FFFFF0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#FFFFF0" nowrap="">0</td>
# <td align="right" bgcolor="#FFFFF0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#FFFFF0" nowrap="">0</td>
# <td align="right" bgcolor="#FFFFF0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#FFFFF0" nowrap="">0</td>
# </tr>
# <tr class="12bk">
# <td align="center" bgcolor="#FFFFF0">外資</td>
# <td align="right" bgcolor="#FFFFF0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#FFFFF0" height="15" nowrap=""><div align="right"></div><div align="right">0</div></td>
# <td align="right" bgcolor="#FFFFF0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#FFFFF0" nowrap="">0</td>
# <td align="right" bgcolor="#FFFFF0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#FFFFF0" nowrap="">0</td>
# <td align="right" bgcolor="#FFFFF0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#FFFFF0" nowrap="">0</td>
# <td align="right" bgcolor="#FFFFF0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#FFFFF0" nowrap="">0</td>
# <td align="right" bgcolor="#FFFFF0" nowrap=""><font color="blue">0</font></td>
# <td align="right" bgcolor="#FFFFF0" nowrap="">0</td>
# </tr>
# </tbody>
# </table>
# </td>
# </tr>
# <tr><td> </td></tr>
# </tbody>
# </table>
# <p>*若以Excel匯入外部資料，請使用<a href="7_12_5_tbl.asp" target="_blank">此連結</a></p>
# </div>
# <script language="javascript">
# function printcontent(){
# 	var s1 = document.getElementById("printhere").innerHTML;
# 	var a1 = s1.search(/javascript:/i);
# 	while (a1 >= 0){
# 		s1 = s1.replace(/javascript:/i , "");
# 		a1 = s1.search(/javascript:/i);
# 	}
# 	a1 = s1.search(/script/i);
# 	while (a1 >= 0){
# 		s1 = s1.replace(/script/i , "div style='display:none' ");
# 		a1 = s1.search(/script/i);
# 	}
#
#
# 	var printPage = window.open("","printPage","");
# 	printPage.document.open();
# 	printPage.document.write("<HTML><head><title>臺灣期貨交易所</title>");
# 	printPage.document.write("<link rel='STYLESHEET' type='text/css' href='../js/rich_calendar/rich_calendar.css' />");
# 	printPage.document.write("<link rel='stylesheet' type='text/css' href='../css/global.css' />");
# 	printPage.document.write("<link rel='stylesheet' type='text/css' href='../css/content.css' />");
# 	printPage.document.write("<link rel='stylesheet' type='text/css' href='../css/con_2.css' />");
# 	printPage.document.write("</head><BODY onload='window.print();window.close();'>");
# 	printPage.document.write("<div class='content'>");
# 	printPage.document.write(s1);
# 	printPage.document.write("</div>");
# 	printPage.document.close("</BODY></HTML>");
# }
# </script>
# <div class="section center"> <a href="javascript:printcontent();"><img src="../images/btn_print.jpg"/></a></div>
# </div>
# </input></input></input></input></input></input></input></form>
# </div>
# <!--SidebarRight End-->
# </div>
# <!--Container End-->
# <!--Footer Start-->
# <div class="fat-footer">
# <table border="0" cellpadding="0" cellspacing="0" width="100%"><tr>
# <td align="left" valign="top" width="20%"><a class="m-one" href="/chinese/3/7_12_1.asp" title="交易資訊">交易資訊</a></td>
# <td align="left" valign="top" width="20%"><a class="m-one" href="/chinese/4/MarketFramework.asp" title="交易制度">交易制度</a></td>
# <td align="left" valign="top" width="20%"><a class="m-one" href="/chinese/5/Clearing.asp" title="結算業務">結算業務</a></td>
# <td align="left" valign="top" width="20%"><a class="m-one" href="/chinese/7/AnnualTrading.asp" title="統計資料">統計資料</a></td>
# <td align="left" valign="top" width="20%"><a class="m-one" href="/chinese/11/News1.asp" title="最新消息">最新消息</a></td>
# </tr><tr>
# <td align="left" valign="top" width="20%">
# <div class="footer_list">
# <ul><li><a class="m-two" href="/chinese/3/3_1_1.asp" title="盤後資訊">盤後資訊</a></li>
# <li><a class="m-two" href="/chinese/3/7_12_1.asp" title="三大法人">三大法人</a></li>
# <li><a class="m-two" href="/chinese/3/7_8.asp" title="大額交易人未沖銷部位結構">大額交易人未沖銷部位結構</a></li>
# <li><a class="m-two" href="/chinese/3/3_5.asp" title="每日外幣參考匯率查詢">每日外幣參考匯率查詢</a></li>
# <li><a class="m-two" href="/chinese/3/AppForm.asp" title="交易歷史資料申請">交易歷史資料申請</a></li>
# <li><a class="m-two" href="/chinese/3/dl_3_1_2.asp" title="資料下載專區">資料下載專區</a></li>
# <li><a class="m-two" href="/chinese/3/InfoVendor.asp" title="資訊廠商">資訊廠商</a></li>
# <li><a class="m-two" href="http://info512.taifex.com.tw" target="_blank" title="台灣期貨交易所行情資訊網站">台灣期貨交易所行情資訊網站</a></li>
# <li><a class="m-two" href="/chinese/3/TradeHalt.asp" title="訊息面暫停交易之股票期貨及選擇權">訊息面暫停交易之股票期貨及選擇權</a></li>
# </ul><td align="left" valign="top" width="20%">
# <div class="footer_list">
# <ul><li><a class="m-two" href="/chinese/4/MarketFramework.asp" title="交易制度">交易制度</a></li>
# <li><a class="m-two" href="/chinese/4/FeeSchedules.asp" title="費率表">費率表</a></li>
# <li><a class="m-two" href="/chinese/4/TradingSystem.asp" title="電子交易系統">電子交易系統</a></li>
# <li><a class="m-two" href="/chinese/4/TraderPL.asp" title="部位限制">部位限制</a></li>
# <li><a class="m-two" href="/chinese/4/FCMList.asp" title="期貨商名冊">期貨商名冊</a></li>
# <li><a class="m-two" href="/chinese/4/Calendar.asp" title="行事曆">行事曆</a></li>
# <li><a class="m-two" href="/chinese/4/ContractAdj.asp" title="股票期貨/選擇權契約調整相關事項">股票期貨/選擇權契約調整相關事項</a></li>
# </ul><td align="left" valign="top" width="20%">
# <div class="footer_list">
# <ul><li><a class="m-two" href="/chinese/5/ClrProcess.asp" title="結算制度">結算制度</a></li>
# <li><a class="m-two" href="/chinese/5/IndexMargining.asp" title="保證金">保證金</a></li>
# <li><a class="m-two" href="/chinese/5/SafeguardSystem.asp" title="財務安全保衛系統">財務安全保衛系統</a></li>
# <li><a class="m-two" href="/chinese/5/CMCriteria.asp" title="結算會員資格標準">結算會員資格標準</a></li>
# <li><a class="m-two" href="/chinese/5/CMList2.asp" title="結算會員名冊">結算會員名冊</a></li>
# <li><a class="m-two" href="/chinese/5/PositionManagement.asp" title="部位管理">部位管理</a></li>
# <li><a class="m-two" href="/chinese/5/FutIndxFSP.asp" title="最後結算價一覽表">最後結算價一覽表</a></li>
# <li><a class="m-two" href="/chinese/5/FutIndxPosSettled.asp" title="到期契約履約交割說明">到期契約履約交割說明</a></li>
# <li><a class="m-two" href="/chinese/5/SettledBond.asp" title="可交割債券轉換因子表">可交割債券轉換因子表</a></li>
# <li><a class="m-two" href="/chinese/4/FeeSchedules.asp?menuid1=05" title="費率表">費率表</a></li>
# </ul><td align="left" valign="top" width="20%">
# <div class="footer_list">
# <ul><li><a class="m-two" href="/chinese/7/DailyFCM.asp" title="期貨商交易量日報表">期貨商交易量日報表</a></li>
# <li><a class="m-two" href="/chinese/7/WeeklyFCM.asp" title="期貨商交易量週報表">期貨商交易量週報表</a></li>
# <li><a class="m-two" href="/chinese/7/MonthlyFCM.asp" title="期貨商交易量月報表">期貨商交易量月報表</a></li>
# <li><a class="m-two" href="/chinese/7/YearlyFCM.asp" title="期貨商交易量年報表">期貨商交易量年報表</a></li>
# <li><a class="m-two" href="/chinese/7/AnnualTrading.asp" title="各商品年成交量統計表">各商品年成交量統計表</a></li>
# <li><a class="m-two" href="/chinese/7/MarketParticipant.asp" title="市場參與者統計">市場參與者統計</a></li>
# <li><a class="m-two" href="/chinese/7/7_10.asp" title="各類交易人各商品交易量統計表">各類交易人各商品交易量統計表</a></li>
# <li><a class="m-two" href="/chinese/7/TradingStatistics1.asp" title="經紀、自營商交易量統計表">經紀、自營商交易量統計表</a></li>
# <li><a class="m-two" href="/chinese/7/TradingStatistics2.asp" title="各類交易人交易量統計表">各類交易人交易量統計表</a></li>
# <li><a class="m-two" href="/chinese/7/trade_volume.xls" target="_blank" title="前一月份各商品每日交易量統計表 ">前一月份各商品每日交易量統計表 </a></li>
# <li><a class="m-two" href="/chinese/7/VIXMinQuotesNew.asp" title="臺指選擇權波動率指數下載">臺指選擇權波動率指數下載</a></li>
# <li><a class="m-two" href="/chinese/7/va01.asp" title="加值資料集">加值資料集</a></li>
# </ul><td align="left" valign="top" width="20%">
# <div class="footer_list">
# <ul><li><a class="m-two" href="/chinese/11/News1.asp" title="公告">公告</a></li>
# <li><a class="m-two" href="/chinese/11/News2.asp" title="新聞稿">新聞稿</a></li>
# <li><a class="m-two" href="/chinese/11/News3.asp" title="股票期貨/選擇權契約調整">股票期貨/選擇權契約調整</a></li>
# <li><a class="m-two" href="/chinese/11/HisNews.asp" title="歷史資料區">歷史資料區</a></li>
# <li><a class="m-two" href="/chinese/11/DailyMarketInfo.asp" title="每日市場資訊">每日市場資訊</a></li>
# <li><a class="m-two" href="/chinese/11/RSS0.asp" title="RSS資訊訂閱服務">RSS資訊訂閱服務</a></li>
# </ul></div></td></div></td></div></td></div></td></div></td></tr></table>
# <table bgcolor="#004ea2" border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td align="left" valign="top" width="3%"></td>
# <td align="left" valign="middle" width="68%">
# <span class="sublink">
# <a class="link-a" href="/chinese/edu/privacy.asp" target="_blank" title="隱私權保護說明"><font color="white">隱私權保護說明</font></a>|
# 		<a class="link-a" href="/chinese/edu/use.asp" target="_blank" title="使用條款"><font color="white">使用條款</font></a>|
#     	<a class="link-a" href="/chinese/isp.pdf" target="_blank" title="資訊安全政策宣言"><font color="white">資訊安全政策宣言</font></a>|
#     	<a class="link-a" href="/chinese/11/RSS0.asp" target="_blank" title="RSS專區"><font color="white">RSS專區</font></a>|
#     	<a class="link-a" href="/chinese/9/9_7.asp" target="_blank" title="常見問題"><font color="white">常見問題</font></a>|
# 		<a class="link-a" href="http://www8.www.gov.tw/policy/2009career/" target="_blank" title="就業資訊"><font color="white">就業資訊</font></a>
# </span>
# </td>
# <td align="left" valign="middle" width="29%">
# <span class="sublink">
# </span>
# </td>
# </tr>
# </table>
# </div>
# <div class="footer clearfix">
# <div class="copyright">臺灣期貨交易所 Taiwan Futures Exchange 100 臺北市羅斯福路二段100號14樓<br/>
#             Tel: (02) 2369-5678    Fax: (02) 2365-7272         <a href="/chinese/edu/service.asp" target="_blank">服務信箱(service@taifex.com.tw)</a> <br/>
#             臺灣期貨交易所 免付費服務專線：0800-075-566     螢幕解析度建議：1024X768 </div>
# <!--
# 	<div class="line_pc"><a href="http://line.naver.jp/R/msg/text/?http%3A%2F%2F59%2E120%2E135%2E116%2Fchinese%2F3%2F7%5F12%5F5%2Easp"></a></div>
# -->
# <div class="qrcode"><a href="/m_chinese/index.asp"></a></div>
# <div class="phone"><a href="/m_chinese/index.asp"></a></div>
# </div>
# <!--Footer End-->
# </div>
# </body>
# </html>
